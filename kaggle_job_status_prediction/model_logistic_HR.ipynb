# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = read.csv("../input/factors-affecting-campus-placement//Placement_Data_Full_Class.csv")
# head(data)
str(data)

# %%
library(caret)

train_index = createDataPartition(y, p = .8, list = FALSE, times = 1)

train_data = data[ train_index, ]
test_data  = data[-train_index, ]

# %%
logsitic_model = glm(status ~ gender + ssc_p + hsc_p + workex + etest_p + specialisation + mba_p,
                     data=train_data, family='binomial')

summary(logsitic_model)

# %%
logsitic_model_2 = glm(status ~ gender + ssc_p + hsc_p + workex + specialisation + mba_p,
                     data=train_data, family='binomial')

summary(logsitic_model_2)

# %%
logsitic_model_3 = glm(status ~ gender + ssc_p + hsc_p + workex + mba_p,
                     data=train_data, family='binomial')

summary(logsitic_model_3)

# %%
final_model = glm(status ~ ssc_p + hsc_p + workex + mba_p,
                     data=train_data, family='binomial')

summary(final_model)

# %%
library(car)

vif(final_model)

# %%
pred = predict(final_model, test_data, type="response")
pred = ifelse(pred >= 0.5, 1, 0)
print(pred)

# %%
confusionMatrix(as.factor(pred + 1), as.factor(as.numeric(test_data$status)))
