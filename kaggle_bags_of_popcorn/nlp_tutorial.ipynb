# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/word2vec-nlp-tutorial/labeledTrainData.tsv.zip
# /kaggle/input/word2vec-nlp-tutorial/sampleSubmission.csv
# /kaggle/input/word2vec-nlp-tutorial/testData.tsv.zip
# /kaggle/input/word2vec-nlp-tutorial/unlabeledTrainData.tsv.zip

# %%
df = pd.read_csv("/kaggle/input/word2vec-nlp-tutorial/labeledTrainData.tsv.zip",
                header=0, delimiter='\t', quoting=3)

df.head()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %%
import re
from bs4 import BeautifulSoup as bs

# 특수 문자 제거하기
def preprocessing(x):
    x = bs(x, 'html.parser').get_text()
    x = re.sub('\W', " ", x)
    
    return x

df['review'] = df['review'].map(lambda x: preprocessing(x))
df.head()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1   With all this stuff going down at the moment ...
# 1  "2381_9"          1     The Classic War of the Worlds   by Timothy ...
# 2  "7759_3"          0   The film starts with a manager  Nicholas Bell...
# 3  "3630_4"          0   It must be assumed that those who praised thi...
# 4  "9495_8"          1   Superbly trashy and wondrously unpretentious ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# 불용어 제거 및 토큰화
def tokenizing(words):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(words.lower())
    words = [x for x in words if x not in stop_words]
    
    return words

df['words'] = df['review'].map(lambda x : tokenizing(x))
df.head()
# Out:
#          id  sentiment                                             review  \
# 0  "5814_8"          1   With all this stuff going down at the moment ...
# 1  "2381_9"          1     The Classic War of the Worlds   by Timothy ...
# 2  "7759_3"          0   The film starts with a manager  Nicholas Bell...
# 3  "3630_4"          0   It must be assumed that those who praised thi...
# 4  "9495_8"          1   Superbly trashy and wondrously unpretentious ...
#
#                                                words
# 0  [stuff, going, moment, mj, started, listening,...
# 1  [classic, war, worlds, timothy, hines, enterta...
# 2  [film, starts, manager, nicholas, bell, giving...
# 3  [must, assumed, praised, film, greatest, filme...
# 4  [superbly, trashy, wondrously, unpretentious, ...

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer

# 토큰을 인덱스로 바꿔줌
token = Tokenizer()
token.fit_on_texts(df['words'])

df['vector'] = token.texts_to_sequences(df['words'])
df.head()
# Out:
#          id  sentiment                                             review  \
# 0  "5814_8"          1   With all this stuff going down at the moment ...
# 1  "2381_9"          1     The Classic War of the Worlds   by Timothy ...
# 2  "7759_3"          0   The film starts with a manager  Nicholas Bell...
# 3  "3630_4"          0   It must be assumed that those who praised thi...
# 4  "9495_8"          1   Superbly trashy and wondrously unpretentious ...
#
#                                                words  \
# 0  [stuff, going, moment, mj, started, listening,...
# 1  [classic, war, worlds, timothy, hines, enterta...
# 2  [film, starts, manager, nicholas, bell, giving...
# 3  [must, assumed, praised, film, greatest, filme...
# 4  [superbly, trashy, wondrously, unpretentious, ...
#
#                                               vector
# 0  [410, 71, 425, 8956, 511, 2484, 116, 54, 881, ...
# 1  [236, 207, 3086, 3611, 7239, 321, 2, 411, 155,...
# 2  [2, 388, 2854, 4457, 3780, 604, 2210, 18035, 5...
# 3  [101, 4896, 5399, 2, 688, 670, 1272, 42, 215, ...
# 4  [3409, 4193, 37747, 11135, 859, 2062, 13202, 1...

# %%
# 단어 사전 확인

vocab = token.word_index
vocab
# Out:
# {'movie': 1,
#  'film': 2,
#  'one': 3,
#  'like': 4,
#  'good': 5,
#  'time': 6,
#  'even': 7,
#  'would': 8,
#  'story': 9,
#  'really': 10,
#  'see': 11,
#  'well': 12,
#  'much': 13,
#  'get': 14,
#  'bad': 15,
#  'people': 16,
#  'also': 17,
#  'first': 18,
#  'great': 19,
#  'made': 20,
#  'way': 21,
#  'make': 22,
#  'could': 23,
#  'movies': 24,
#  'think': 25,
#  'characters': 26,
#  'character': 27,
#  'watch': 28,
#  'two': 29,
#  'films': 30,
#  'seen': 31,
#  'many': 32,
#  'life': 33,
#  'plot': 34,
#  'acting': 35,
#  'never': 36,
#  'love': 37,
#  'little': 38,
#  'best': 39,
#  'show': 40,
#  'know': 41,
#  'ever': 42,
#  'man': 43,
#  'better': 44,
#  'end': 45,
#  'still': 46,
#  'say': 47,
#  'scene': 48,
#  'scenes': 49,
#  'go': 50,
#  'something': 51,
#  'back': 52,
#  'real': 53,
#  'watching': 54,
#  'though': 55,
#  'old': 56,
#  'thing': 57,
#  'years': 58,
#  'actors': 59,
#  'director': 60,
#  'work': 61,
#  'another': 62,
#  'new': 63,
#  'nothing': 64,
#  'funny': 65,
#  '10': 66,
#  'actually': 67,
#  'makes': 68,
#  'look': 69,
#  'find': 70,
#  'going': 71,
#  'part': 72,
#  'lot': 73,
#  'every': 74,
#  'world': 75,
#  'cast': 76,
#  'us': 77,
#  'quite': 78,
#  'got': 79,
#  'want': 80,
#  'things': 81,
#  'pretty': 82,
#  'young': 83,
#  'seems': 84,
#  'around': 85,
#  'horror': 86,
#  'however': 87,
#  'fact': 88,
#  'take': 89,
#  'big': 90,
#  'enough': 91,
#  'long': 92,
#  'thought': 93,
#  'series': 94,
#  'may': 95,
#  'give': 96,
#  'original': 97,
#  'action': 98,
#  'right': 99,
#  'without': 100,
#  'must': 101,
#  'comedy': 102,
#  'always': 103,
#  'times': 104,
#  'point': 105,
#  'gets': 106,
#  'family': 107,
#  'come': 108,
#  'role': 109,
#  'saw': 110,
#  'almost': 111,
#  'interesting': 112,
#  'least': 113,
#  'done': 114,
#  'whole': 115,
#  'music': 116,
#  'bit': 117,
#  'guy': 118,
#  'script': 119,
#  'far': 120,
#  'making': 121,
#  'feel': 122,
#  'anything': 123,
#  'minutes': 124,
#  'last': 125,
#  'might': 126,
#  'since': 127,
#  'performance': 128,
#  '2': 129,
#  'girl': 130,
#  'probably': 131,
#  'woman': 132,
#  'kind': 133,
#  'tv': 134,
#  'away': 135,
#  'yet': 136,
#  'day': 137,
#  'rather': 138,
#  'worst': 139,
#  'fun': 140,
#  'sure': 141,
#  'hard': 142,
#  'anyone': 143,
#  'played': 144,
#  'found': 145,
#  'although': 146,
#  'especially': 147,
#  'course': 148,
#  'believe': 149,
#  'screen': 150,
#  'comes': 151,
#  'looking': 152,
#  'trying': 153,
#  'set': 154,
#  'goes': 155,
#  'book': 156,
#  'looks': 157,
#  'place': 158,
#  'actor': 159,
#  'different': 160,
#  'put': 161,
#  'money': 162,
#  'year': 163,
#  'ending': 164,
#  'dvd': 165,
#  'let': 166,
#  'maybe': 167,
#  'someone': 168,
#  'true': 169,
#  'sense': 170,
#  'reason': 171,
#  'everything': 172,
#  'shows': 173,
#  'three': 174,
#  'worth': 175,
#  'job': 176,
#  'main': 177,
#  'together': 178,
#  'watched': 179,
#  'play': 180,
#  'american': 181,
#  'everyone': 182,
#  'plays': 183,
#  'john': 184,
#  '1': 185,
#  'effects': 186,
#  'later': 187,
#  'audience': 188,
#  'said': 189,
#  'takes': 190,
#  'instead': 191,
#  'house': 192,
#  'beautiful': 193,
#  'seem': 194,
#  'high': 195,
#  'night': 196,
#  'version': 197,
#  'wife': 198,
#  'left': 199,
#  'father': 200,
#  'special': 201,
#  'seeing': 202,
#  'half': 203,
#  'star': 204,
#  'excellent': 205,
#  'shot': 206,
#  'war': 207,
#  'idea': 208,
#  'black': 209,
#  'nice': 210,
#  'less': 211,
#  'else': 212,
#  'mind': 213,
#  'simply': 214,
#  'read': 215,
#  'second': 216,
#  'fan': 217,
#  'men': 218,
#  'death': 219,
#  'hollywood': 220,
#  '3': 221,
#  'poor': 222,
#  'help': 223,
#  'completely': 224,
#  'dead': 225,
#  'used': 226,
#  'home': 227,
#  'line': 228,
#  'either': 229,
#  'short': 230,
#  'top': 231,
#  'given': 232,
#  'kids': 233,
#  'budget': 234,
#  'try': 235,
#  'classic': 236,
#  'performances': 237,
#  'wrong': 238,
#  'women': 239,
#  'enjoy': 240,
#  'boring': 241,
#  'need': 242,
#  'rest': 243,
#  'use': 244,
#  'low': 245,
#  'production': 246,
#  'friends': 247,
#  'full': 248,
#  'camera': 249,
#  'along': 250,
#  'truly': 251,
#  'video': 252,
#  'awful': 253,
#  'couple': 254,
#  'tell': 255,
#  'next': 256,
#  'remember': 257,
#  'stupid': 258,
#  'start': 259,
#  'stars': 260,
#  'mean': 261,
#  'sex': 262,
#  'perhaps': 263,
#  'came': 264,
#  'recommend': 265,
#  'moments': 266,
#  'school': 267,
#  'episode': 268,
#  'wonderful': 269,
#  'small': 270,
#  'face': 271,
#  'understand': 272,
#  'terrible': 273,
#  'playing': 274,
#  'getting': 275,
#  'written': 276,
#  'early': 277,
#  'name': 278,
#  'often': 279,
#  'keep': 280,
#  'style': 281,
#  'perfect': 282,
#  'human': 283,
#  'person': 284,
#  'others': 285,
#  'definitely': 286,
#  'gives': 287,
#  'boy': 288,
#  'lost': 289,
#  'live': 290,
#  'lines': 291,
#  'become': 292,
#  'dialogue': 293,
#  'head': 294,
#  'finally': 295,
#  'piece': 296,
#  'yes': 297,
#  'case': 298,
#  'felt': 299,
#  'mother': 300,
#  'liked': 301,
#  'supposed': 302,
#  'children': 303,
#  'title': 304,
#  'white': 305,
#  'cinema': 306,
#  'absolutely': 307,
#  'picture': 308,
#  'sort': 309,
#  'worse': 310,
#  'went': 311,
#  'certainly': 312,
#  'entire': 313,
#  'waste': 314,
#  'killer': 315,
#  'problem': 316,
#  'oh': 317,
#  'mr': 318,
#  'evil': 319,
#  'hope': 320,
#  'entertaining': 321,
#  'friend': 322,
#  'called': 323,
#  'based': 324,
#  'overall': 325,
#  'loved': 326,
#  'fans': 327,
#  'several': 328,
#  'drama': 329,
#  'beginning': 330,
#  'lives': 331,
#  'care': 332,
#  '5': 333,
#  'already': 334,
#  'dark': 335,
#  'becomes': 336,
#  'laugh': 337,
#  'example': 338,
#  'direction': 339,
#  '4': 340,
#  'despite': 341,
#  'seemed': 342,
#  'throughout': 343,
#  'turn': 344,
#  'son': 345,
#  'wanted': 346,
#  'unfortunately': 347,
#  'michael': 348,
#  'history': 349,
#  'final': 350,
#  'heart': 351,
#  'fine': 352,
#  'amazing': 353,
#  'child': 354,
#  'sound': 355,
#  'humor': 356,
#  'lead': 357,
#  'guess': 358,
#  'totally': 359,
#  'writing': 360,
#  'guys': 361,
#  'quality': 362,
#  'close': 363,
#  'art': 364,
#  'wants': 365,
#  'b': 366,
#  'game': 367,
#  'behind': 368,
#  'town': 369,
#  'works': 370,
#  'side': 371,
#  'tries': 372,
#  'days': 373,
#  'past': 374,
#  'viewer': 375,
#  'able': 376,
#  'flick': 377,
#  'hand': 378,
#  'genre': 379,
#  'turns': 380,
#  'act': 381,
#  'enjoyed': 382,
#  'today': 383,
#  'kill': 384,
#  'favorite': 385,
#  'car': 386,
#  'soon': 387,
#  'starts': 388,
#  'actress': 389,
#  'run': 390,
#  'sometimes': 391,
#  'gave': 392,
#  'eyes': 393,
#  'etc': 394,
#  'girls': 395,
#  'late': 396,
#  'god': 397,
#  'directed': 398,
#  'horrible': 399,
#  'kid': 400,
#  'brilliant': 401,
#  'city': 402,
#  'parts': 403,
#  'blood': 404,
#  'self': 405,
#  'hour': 406,
#  'thinking': 407,
#  'stories': 408,
#  'expect': 409,
#  'stuff': 410,
#  'obviously': 411,
#  'decent': 412,
#  'voice': 413,
#  'writer': 414,
#  'fight': 415,
#  'highly': 416,
#  'feeling': 417,
#  'daughter': 418,
#  'slow': 419,
#  'except': 420,
#  'matter': 421,
#  'type': 422,
#  'age': 423,
#  'anyway': 424,
#  'moment': 425,
#  'roles': 426,
#  'heard': 427,
#  'killed': 428,
#  'says': 429,
#  'brother': 430,
#  'leave': 431,
#  'took': 432,
#  'police': 433,
#  'strong': 434,
#  'violence': 435,
#  'hit': 436,
#  'stop': 437,
#  'happens': 438,
#  'known': 439,
#  'particularly': 440,
#  'happened': 441,
#  'involved': 442,
#  'extremely': 443,
#  'james': 444,
#  'chance': 445,
#  'obvious': 446,
#  'murder': 447,
#  'living': 448,
#  'told': 449,
#  'coming': 450,
#  'alone': 451,
#  'experience': 452,
#  'lack': 453,
#  'hero': 454,
#  'including': 455,
#  'attempt': 456,
#  'please': 457,
#  'happen': 458,
#  'crap': 459,
#  'gore': 460,
#  'wonder': 461,
#  'complete': 462,
#  'cut': 463,
#  'group': 464,
#  'interest': 465,
#  'ago': 466,
#  'none': 467,
#  'score': 468,
#  'husband': 469,
#  'hell': 470,
#  'david': 471,
#  'save': 472,
#  'simple': 473,
#  'ok': 474,
#  'looked': 475,
#  'song': 476,
#  'career': 477,
#  'number': 478,
#  'seriously': 479,
#  'king': 480,
#  'possible': 481,
#  'sad': 482,
#  'annoying': 483,
#  'exactly': 484,
#  'shown': 485,
#  'running': 486,
#  'musical': 487,
#  'serious': 488,
#  'scary': 489,
#  'reality': 490,
#  'released': 491,
#  'taken': 492,
#  'whose': 493,
#  'english': 494,
#  'ends': 495,
#  'cinematography': 496,
#  'usually': 497,
#  'opening': 498,
#  'hours': 499,
#  'jokes': 500,
#  'light': 501,
#  'body': 502,
#  'hilarious': 503,
#  'cool': 504,
#  'across': 505,
#  'relationship': 506,
#  'somewhat': 507,
#  'usual': 508,
#  'happy': 509,
#  'ridiculous': 510,
#  'started': 511,
#  'level': 512,
#  'view': 513,
#  'change': 514,
#  'opinion': 515,
#  'novel': 516,
#  'wish': 517,
#  'middle': 518,
#  'taking': 519,
#  'talking': 520,
#  'documentary': 521,
#  'ones': 522,
#  'robert': 523,
#  'order': 524,
#  'finds': 525,
#  'power': 526,
#  'shots': 527,
#  'saying': 528,
#  'room': 529,
#  'female': 530,
#  'huge': 531,
#  'mostly': 532,
#  'episodes': 533,
#  'country': 534,
#  'five': 535,
#  'talent': 536,
#  'important': 537,
#  'modern': 538,
#  'earth': 539,
#  'rating': 540,
#  'major': 541,
#  'strange': 542,
#  'word': 543,
#  'turned': 544,
#  'jack': 545,
#  'call': 546,
#  'single': 547,
#  'apparently': 548,
#  'disappointed': 549,
#  'four': 550,
#  'events': 551,
#  'due': 552,
#  'songs': 553,
#  'attention': 554,
#  'basically': 555,
#  'television': 556,
#  '7': 557,
#  'comic': 558,
#  'knows': 559,
#  'future': 560,
#  'clearly': 561,
#  'supporting': 562,
#  'british': 563,
#  'non': 564,
#  'knew': 565,
#  'paul': 566,
#  'fast': 567,
#  '8': 568,
#  'thriller': 569,
#  'class': 570,
#  'easily': 571,
#  'cheap': 572,
#  'silly': 573,
#  'problems': 574,
#  'words': 575,
#  'miss': 576,
#  'tells': 577,
#  'entertainment': 578,
#  'local': 579,
#  'rock': 580,
#  'sequence': 581,
#  'bring': 582,
#  'beyond': 583,
#  'straight': 584,
#  'george': 585,
#  'oscar': 586,
#  'upon': 587,
#  'whether': 588,
#  'predictable': 589,
#  'moving': 590,
#  'romantic': 591,
#  'sets': 592,
#  'similar': 593,
#  'falls': 594,
#  'review': 595,
#  'mystery': 596,
#  'lady': 597,
#  'eye': 598,
#  'richard': 599,
#  'talk': 600,
#  'enjoyable': 601,
#  'appears': 602,
#  'needs': 603,
#  'giving': 604,
#  'within': 605,
#  'message': 606,
#  'ten': 607,
#  'theater': 608,
#  'animation': 609,
#  'near': 610,
#  'team': 611,
#  'sister': 612,
#  'sequel': 613,
#  'red': 614,
#  'theme': 615,
#  'dull': 616,
#  'nearly': 617,
#  'stand': 618,
#  'points': 619,
#  'lee': 620,
#  'bunch': 621,
#  'mention': 622,
#  'feels': 623,
#  'add': 624,
#  'york': 625,
#  'release': 626,
#  'ways': 627,
#  'storyline': 628,
#  'easy': 629,
#  'surprised': 630,
#  'using': 631,
#  'lots': 632,
#  'named': 633,
#  'fantastic': 634,
#  'begins': 635,
#  'working': 636,
#  'actual': 637,
#  'die': 638,
#  'effort': 639,
#  'feature': 640,
#  'tale': 641,
#  'hate': 642,
#  'french': 643,
#  'minute': 644,
#  'stay': 645,
#  'clear': 646,
#  '9': 647,
#  'viewers': 648,
#  'follow': 649,
#  'tom': 650,
#  'elements': 651,
#  'among': 652,
#  'comments': 653,
#  'typical': 654,
#  'avoid': 655,
#  'showing': 656,
#  'editing': 657,
#  'tried': 658,
#  'famous': 659,
#  'sorry': 660,
#  'peter': 661,
#  'fall': 662,
#  'season': 663,
#  'dialog': 664,
#  'period': 665,
#  'form': 666,
#  'general': 667,
#  'certain': 668,
#  'soundtrack': 669,
#  'filmed': 670,
#  'buy': 671,
#  'parents': 672,
#  'check': 673,
#  'means': 674,
#  'weak': 675,
#  'material': 676,
#  'figure': 677,
#  'realistic': 678,
#  'doubt': 679,
#  'somehow': 680,
#  'crime': 681,
#  'gone': 682,
#  'space': 683,
#  'disney': 684,
#  'leads': 685,
#  'kept': 686,
#  'viewing': 687,
#  'greatest': 688,
#  'dance': 689,
#  'lame': 690,
#  'zombie': 691,
#  'third': 692,
#  'suspense': 693,
#  'imagine': 694,
#  'brought': 695,
#  'atmosphere': 696,
#  'hear': 697,
#  'whatever': 698,
#  'particular': 699,
#  'de': 700,
#  'sequences': 701,
#  'america': 702,
#  'move': 703,
#  'indeed': 704,
#  'eventually': 705,
#  'learn': 706,
#  'average': 707,
#  'rent': 708,
#  'note': 709,
#  'wait': 710,
#  'deal': 711,
#  'reviews': 712,
#  'forget': 713,
#  'surprise': 714,
#  'japanese': 715,
#  'stage': 716,
#  'poorly': 717,
#  'premise': 718,
#  'nature': 719,
#  'believable': 720,
#  'sexual': 721,
#  'subject': 722,
#  'sit': 723,
#  'possibly': 724,
#  'okay': 725,
#  'decided': 726,
#  'expected': 727,
#  'imdb': 728,
#  'dr': 729,
#  'truth': 730,
#  '20': 731,
#  'street': 732,
#  'free': 733,
#  'became': 734,
#  'difficult': 735,
#  'screenplay': 736,
#  'romance': 737,
#  'killing': 738,
#  'baby': 739,
#  'joe': 740,
#  'hot': 741,
#  'dog': 742,
#  'reading': 743,
#  'question': 744,
#  'needed': 745,
#  'leaves': 746,
#  'begin': 747,
#  'meets': 748,
#  'unless': 749,
#  'directors': 750,
#  'credits': 751,
#  'society': 752,
#  'superb': 753,
#  'shame': 754,
#  'otherwise': 755,
#  'write': 756,
#  'situation': 757,
#  'meet': 758,
#  'dramatic': 759,
#  'memorable': 760,
#  'male': 761,
#  'open': 762,
#  'dream': 763,
#  'weird': 764,
#  'badly': 765,
#  'earlier': 766,
#  'writers': 767,
#  'forced': 768,
#  'fi': 769,
#  'laughs': 770,
#  'sci': 771,
#  'acted': 772,
#  'emotional': 773,
#  'crazy': 774,
#  'jane': 775,
#  'older': 776,
#  'beauty': 777,
#  'monster': 778,
#  'realize': 779,
#  'comment': 780,
#  'deep': 781,
#  'footage': 782,
#  'forward': 783,
#  'interested': 784,
#  'fantasy': 785,
#  'ask': 786,
#  'sounds': 787,
#  'plus': 788,
#  'mark': 789,
#  'directing': 790,
#  'e': 791,
#  'features': 792,
#  'keeps': 793,
#  'development': 794,
#  'mess': 795,
#  'quickly': 796,
#  'air': 797,
#  'creepy': 798,
#  'towards': 799,
#  'box': 800,
#  'perfectly': 801,
#  'girlfriend': 802,
#  'worked': 803,
#  'cheesy': 804,
#  'setting': 805,
#  'unique': 806,
#  'bill': 807,
#  'effect': 808,
#  'fire': 809,
#  'plenty': 810,
#  'result': 811,
#  'hands': 812,
#  'previous': 813,
#  'total': 814,
#  'brings': 815,
#  'personal': 816,
#  'rate': 817,
#  'incredibly': 818,
#  'doctor': 819,
#  'return': 820,
#  'business': 821,
#  'christmas': 822,
#  'joke': 823,
#  'leading': 824,
#  'casting': 825,
#  'apart': 826,
#  'admit': 827,
#  'powerful': 828,
#  'cop': 829,
#  'appear': 830,
#  '30': 831,
#  'background': 832,
#  'boys': 833,
#  'ben': 834,
#  'present': 835,
#  'era': 836,
#  'battle': 837,
#  'meant': 838,
#  'hardly': 839,
#  'telling': 840,
#  'potential': 841,
#  'create': 842,
#  'secret': 843,
#  'break': 844,
#  'masterpiece': 845,
#  'pay': 846,
#  'gay': 847,
#  'dumb': 848,
#  'political': 849,
#  'fighting': 850,
#  'twist': 851,
#  'fails': 852,
#  'various': 853,
#  'portrayed': 854,
#  'co': 855,
#  'western': 856,
#  'villain': 857,
#  'inside': 858,
#  '80': 859,
#  'nudity': 860,
#  'reasons': 861,
#  'william': 862,
#  'outside': 863,
#  'ideas': 864,
#  'front': 865,
#  'missing': 866,
#  'deserves': 867,
#  'married': 868,
#  'match': 869,
#  'expecting': 870,
#  'rich': 871,
#  'fairly': 872,
#  'talented': 873,
#  'success': 874,
#  'list': 875,
#  'unlike': 876,
#  'remake': 877,
#  'manages': 878,
#  'scott': 879,
#  'attempts': 880,
#  'odd': 881,
#  'social': 882,
#  'c': 883,
#  'cute': 884,
#  'recently': 885,
#  'flat': 886,
#  'sadly': 887,
#  'copy': 888,
#  'wrote': 889,
#  'agree': 890,
#  'sweet': 891,
#  'cold': 892,
#  'crew': 893,
#  'spoilers': 894,
#  'plain': 895,
#  'mary': 896,
#  'office': 897,
#  'filmmakers': 898,
#  'missed': 899,
#  'following': 900,
#  'mentioned': 901,
#  'public': 902,
#  'gun': 903,
#  'incredible': 904,
#  'pure': 905,
#  'wasted': 906,
#  'brothers': 907,
#  'large': 908,
#  'ended': 909,
#  'caught': 910,
#  'revenge': 911,
#  'produced': 912,
#  'members': 913,
#  'filled': 914,
#  'la': 915,
#  'pace': 916,
#  'popular': 917,
#  'party': 918,
#  'science': 919,
#  'waiting': 920,
#  'water': 921,
#  'cat': 922,
#  'decides': 923,
#  'considering': 924,
#  'cartoon': 925,
#  'hold': 926,
#  'spirit': 927,
#  'created': 928,
#  'slightly': 929,
#  'tension': 930,
#  '6': 931,
#  'uses': 932,
#  'convincing': 933,
#  'escape': 934,
#  'fear': 935,
#  'suddenly': 936,
#  'compared': 937,
#  'familiar': 938,
#  'neither': 939,
#  'sees': 940,
#  'spent': 941,
#  'island': 942,
#  'cause': 943,
#  'intelligent': 944,
#  'state': 945,
#  'clever': 946,
#  'entirely': 947,
#  'credit': 948,
#  'moves': 949,
#  'kills': 950,
#  'bored': 951,
#  '90': 952,
#  'band': 953,
#  'language': 954,
#  'century': 955,
#  'laughing': 956,
#  'choice': 957,
#  'dancing': 958,
#  'italian': 959,
#  'cover': 960,
#  'successful': 961,
#  'value': 962,
#  'violent': 963,
#  'visual': 964,
#  '15': 965,
#  'trouble': 966,
#  'speak': 967,
#  'tony': 968,
#  'ultimately': 969,
#  'concept': 970,
#  'singing': 971,
#  'store': 972,
#  'basic': 973,
#  'zombies': 974,
#  'positive': 975,
#  'studio': 976,
#  'german': 977,
#  'animated': 978,
#  'exciting': 979,
#  'company': 980,
#  'biggest': 981,
#  'force': 982,
#  'consider': 983,
#  'runs': 984,
#  'died': 985,
#  'effective': 986,
#  'walk': 987,
#  'depth': 988,
#  'adventure': 989,
#  'control': 990,
#  'law': 991,
#  'recent': 992,
#  'adult': 993,
#  'amusing': 994,
#  'former': 995,
#  'common': 996,
#  'spend': 997,
#  'portrayal': 998,
#  'focus': 999,
#  'appreciate': 1000,
#  ...}

# %%
vocab["<PAD>"] = 0
len(vocab)
# Out:
# 75789

# %%
# 최대 길이 기준 75%로 max length 설정

print("min word length", df['vector'].map(lambda x : len(x)).min())
print("25% word length", df['vector'].map(lambda x : len(x)).quantile(0.25))
print("50% word length",df['vector'].map(lambda x : len(x)).quantile(0.50))
print("75% word length",df['vector'].map(lambda x : len(x)).quantile(0.75))
print("max word length",df['vector'].map(lambda x : len(x)).max())
# Out:
# min word length 4
# 25% word length 64.0
# 50% word length 90.0
# 75% word length 148.0
# max word length 1429

# %%
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

max_padding = df['vector'].map(lambda x : len(x)).quantile(0.75).astype(int)

# max length에 맞추어 길이 변경 / padding 혹은 cropping
X_train = pad_sequences(df['vector'],maxlen = max_padding, padding = 'post' )
Y_train = df['sentiment']
print(X_train)
# Out:
# [[26373   121     1 ... 18947   320  1372]
#  [  236   207  3086 ...     0     0     0]
#  [    3   719 18948 ...   707  1187  5398]
#  ...
#  [  118  3144    14 ...     0     0     0]
#  [  831   644   521 ...     0     0     0]
#  [  110     1   354 ...     0     0     0]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# tf-idf 계산
vectorizer = TfidfVectorizer(min_df=0.0, analyzer = "word", sublinear_tf=True,
                           ngram_range=(1,3), max_features=5000, stop_words='english')

tfidf_train = vectorizer.fit_transform(list(df['review']))

print(type(tfidf_train))
print(tfidf_train.shape)
print(tfidf_train[0]) 

# tfidf_train.toarray()
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
# (25000, 5000)
#   (0, 2502)	0.1028129880638737
#   (0, 1285)	0.06783600784085628
#   (0, 4212)	0.09798879691949967
#   (0, 4484)	0.10513903894444403
#   (0, 3287)	0.09207262080751873
#   (0, 2998)	0.09979596337739731
#   (0, 4479)	0.09655916967157495
#   (0, 3286)	0.1049730103164135
#   (0, 37)	0.09626873961802275
#   (0, 2776)	0.09875448073816731
#   (0, 1638)	0.17021192744889807
#   (0, 2448)	0.10116830229528975
#   (0, 2825)	0.171073173099871
#   (0, 2174)	0.06334114094305214
#   (0, 4298)	0.06275013728447221
#   (0, 1559)	0.0683315613411591
#   (0, 1571)	0.050147944199345866
#   (0, 1305)	0.1025268801175609
#   (0, 815)	0.10635206492339642
#   (0, 1204)	0.056885940864640605
#   (0, 1280)	0.03764404759175515
#   (0, 4304)	0.07530453665252453
#   (0, 1875)	0.06589300465590953
#   (0, 312)	0.07042547866816848
#   (0, 3348)	0.08579945561982709
#   :	:
#   (0, 2299)	0.08305401895465898
#   (0, 2022)	0.160515236053926
#   (0, 2890)	0.058087806097562915
#   (0, 2758)	0.038533095865286734
#   (0, 1399)	0.10653310209512738
#   (0, 950)	0.1194356257446557
#   (0, 3606)	0.05932910538681658
#   (0, 4490)	0.05042535821906538
#   (0, 2027)	0.09272701214548547
#   (0, 2303)	0.09506771035938272
#   (0, 699)	0.073285501336439
#   (0, 4796)	0.049430832000672706
#   (0, 2431)	0.0626265245897318
#   (0, 2824)	0.11891941197539346
#   (0, 4829)	0.09595715060955264
#   (0, 1259)	0.07517543346217842
#   (0, 3162)	0.07841337871168738
#   (0, 4833)	0.04607899433847484
#   (0, 3045)	0.09179315875001577
#   (0, 2645)	0.09489067409146293
#   (0, 4202)	0.06964196049374342
#   (0, 4725)	0.07710619316689983
#   (0, 2927)	0.06808186871502951
#   (0, 1923)	0.1008249855090022
#   (0, 4294)	0.06698089637298846

# %%
from sklearn.feature_extraction.text import CountVectorizer ## TF 

# count vectorization 방법
# 발화 단어의 종류를 통해 유사성 판단

vectorizer = CountVectorizer(analyzer = "word", max_features = 5000)
count_train = vectorizer.fit_transform(list(df['review']))
print(count_train.shape)
print(count_train[0])
# Out:
# (25000, 5000)
#   (0, 4917)	4
#   (0, 194)	4
#   (0, 4465)	11
#   (0, 4259)	1
#   (0, 1939)	3
#   (0, 1345)	1
#   (0, 339)	2
#   (0, 4439)	19
#   (0, 2897)	1
#   (0, 4722)	2
#   (0, 4175)	1
#   (0, 2623)	1
#   (0, 4517)	9
#   (0, 2128)	3
#   (0, 2956)	2
#   (0, 4822)	1
#   (0, 3091)	1
#   (0, 1319)	1
#   (0, 2098)	1
#   (0, 233)	10
#   (0, 4451)	1
#   (0, 4820)	2
#   (0, 152)	1
#   (0, 2785)	3
#   (0, 2441)	3
#   :	:
#   (0, 2359)	1
#   (0, 620)	1
#   (0, 1918)	1
#   (0, 4606)	1
#   (0, 4370)	1
#   (0, 1550)	1
#   (0, 1958)	1
#   (0, 3305)	1
#   (0, 4850)	2
#   (0, 353)	1
#   (0, 1885)	1
#   (0, 4269)	1
#   (0, 1332)	1
#   (0, 677)	1
#   (0, 428)	1
#   (0, 1262)	1
#   (0, 457)	1
#   (0, 868)	1
#   (0, 1340)	1
#   (0, 1631)	1
#   (0, 1448)	1
#   (0, 1620)	1
#   (0, 4263)	1
#   (0, 2164)	1
#   (0, 2533)	1

# %%
from gensim.models import word2vec

# word2vec
sentences = []
for review in list(df['review']) :
    sentences.append(review.split())

num_features   = 1000
min_word_count = 20 
context        = 10 # window size
downsampling = 1e-3 # 빈출 단어에 패널티 샘플링 (학습 속도 측면)

w2v = word2vec.Word2Vec(sentences,
                        size=num_features,
                        min_count=min_word_count,
                        window= context,
                        sample=downsampling,
                        iter=10,
                        sg=0 #0: CBOW, 1:skip-gram
                        )

w2v.wv.most_similar("man")
# Out:
# [('woman', 0.6372383832931519),
#  ('lady', 0.6055783033370972),
#  ('soldier', 0.5552583932876587),
#  ('priest', 0.525982677936554),
#  ('guy', 0.5193488001823425),
#  ('doctor', 0.5188654661178589),
#  ('person', 0.5109984874725342),
#  ('farmer', 0.49898603558540344),
#  ('journalist', 0.49807900190353394),
#  ('boy', 0.492019385099411)]

# %%
# w2v로 하나의 문서를 표현하기 위해서 각 단어 벡터의 평균 값을 이용함
def get_features(words, model, num_features):
    feature_vector = np.zeros((num_features), dtype = np.float32)
    
    num_words = 0
    index2word_set = set(model.wv.index2word)
    
    for w in words:
        if w in index2word_set:
            num_words +=1
            feature_vector = np.add(feature_vector, model[w])
            
    feature_vector = np.divide(feature_vector,num_words)
    
    return feature_vector

def get_dataset(reviews, model, num_features):
    dataset = list()
    
    for s in reviews :
        dataset.append(get_features(s,model,num_features))
    
    reviewFeaturevecs = np.stack(dataset)
    
    return reviewFeaturevecs

word2vec_train = get_dataset(sentences, w2v, num_features)
word2vec_train.shape
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()
# (25000, 1000)

# %%
print(f"First document's averaged word vector\n{word2vec_train[0]}")
# Out:
# First document's averaged word vector
# [ 7.92942792e-02  2.71616817e-01  1.81260392e-01  1.22539490e-01
#   9.66486037e-02  6.87005222e-02 -6.72703609e-02 -4.72922325e-02
#   3.01981807e-01 -1.06756156e-02  1.39669299e-01 -1.99800983e-01
#   5.44578359e-02 -1.45156115e-01  4.07924414e-01 -1.14219589e-02
#   6.45725951e-02 -1.19653136e-01 -5.04831791e-01  8.77734497e-02
#   2.10731267e-03 -3.47134583e-02  6.17381632e-02  2.26809662e-02
#  -1.53841987e-01 -9.92677435e-02 -9.16189253e-02  1.32000029e-01
#   2.50606924e-01 -9.03838724e-02  1.22445226e-01  4.58620954e-03
#  -7.17912540e-02  4.26879451e-02  1.73533514e-01  5.08190468e-02
#  -6.92595840e-02  1.63001508e-01 -2.21768498e-01  2.85976380e-01
#   1.38495192e-02  3.84116381e-01  9.68754478e-03 -3.33310187e-01
#  -8.65783729e-03  2.30269924e-01 -5.69937825e-02 -1.76770121e-01
#  -1.32580251e-02  5.54324463e-02 -8.18264950e-03  5.55385016e-02
#  -1.59476176e-01  4.09865588e-01  4.58134664e-03 -1.85977653e-01
#  -5.25313057e-03  1.69091299e-01 -3.39421742e-02  9.90305096e-03
#  -1.08091235e-01 -2.70785898e-01  1.92217022e-01 -1.01729006e-01
#   2.01715305e-01  4.72968221e-02  2.26594165e-01  9.41069052e-02
#  -6.95459694e-02  9.63597186e-03 -4.49488312e-02 -5.02970517e-02
#   1.67240322e-01  3.97421494e-02 -1.28862277e-01 -5.47848754e-02
#  -2.77658235e-02 -1.25267744e-01  7.82240555e-02 -3.16111334e-02
#   4.59573306e-02  4.59680595e-02  4.83513474e-02 -1.31119445e-01
#   3.73479612e-02 -1.17873922e-01 -5.15771173e-02  6.11927826e-03
#  -1.72406644e-01  3.78092714e-02  8.16178024e-02 -8.63576028e-03
#  -8.10359046e-02 -2.59625120e-03 -3.25305457e-03  5.17898425e-02
#   9.19625238e-02  5.51910780e-04  3.72625480e-04 -1.68801889e-01
#  -3.82475667e-02  1.15043551e-01  5.14148036e-03 -1.15894578e-01
#   5.92571422e-02  8.40216577e-02  1.05800748e-01  1.05561865e-02
#  -1.00082844e-01  6.72880411e-02 -5.59461266e-02  4.61009443e-02
#  -1.40820295e-01 -1.60854831e-01  1.39601186e-01 -9.88108888e-02
#  -2.01775119e-01  2.98061837e-02  1.59495473e-01  5.70793264e-03
#   4.59914729e-02  1.15782388e-01  9.11475569e-02  5.30686118e-02
#  -7.07856864e-02  1.32050157e-01 -1.81908682e-02  3.31378914e-02
#   2.08340526e-01  1.53908268e-01 -8.67344737e-02  7.56543651e-02
#  -3.55813690e-02  1.08487502e-01 -1.42533392e-01  9.02226344e-02
#   9.94746909e-02  1.27301902e-01 -2.61086244e-02 -1.56545728e-01
#   3.32900770e-02  1.32553861e-01 -6.59948960e-02 -3.40392329e-02
#   1.31184414e-01 -5.87365627e-02  6.22137301e-02  2.61481069e-02
#  -1.12292491e-01  5.23157939e-02  3.66681218e-02  6.00073487e-02
#  -5.89673333e-02  2.38510162e-01  7.80237317e-02  3.59790698e-02
#   5.87398633e-02  1.74902573e-01 -3.03169489e-02  1.65825143e-01
#  -5.83822727e-02  1.41057298e-01 -1.44697875e-02  1.45335361e-01
#  -1.01661362e-01  7.08539337e-02 -3.37107629e-02 -1.16772078e-01
#   8.49317610e-02 -3.82636078e-02  3.64920385e-02 -3.59159708e-01
#  -6.71006888e-02 -1.06655329e-01 -1.19818717e-01 -1.84024811e-01
#  -4.16977629e-02 -1.29598171e-01  4.44691330e-02  1.22153744e-01
#   2.87963331e-01  1.81175411e-01 -1.67787537e-01  2.80505657e-01
#  -2.34066650e-01  1.77430704e-01 -1.33041153e-02 -1.48851529e-01
#   2.53081977e-01 -2.00276613e-01  1.21560358e-01  1.28544560e-02
#  -3.88803259e-02  5.58096543e-02  1.74623311e-01 -1.85319349e-01
#  -1.53886780e-01 -4.82725389e-02  1.66973018e-03  1.87500529e-02
#  -7.61432797e-02 -1.43816546e-01 -8.15884843e-02 -9.49787125e-02
#  -1.39437824e-01  9.13150087e-02  1.16760850e-01 -4.03140001e-02
#  -1.78690314e-01 -6.50509596e-02  2.59597898e-01 -2.85085905e-02
#  -2.99059134e-02  1.47273066e-04 -4.53884751e-02 -1.49444386e-01
#   1.42583147e-01 -1.13532916e-01  1.10723361e-01  3.60704988e-01
#   1.04787380e-01 -4.10039574e-01  5.68187758e-02  4.34894785e-02
#  -5.20336954e-03  5.39678410e-02  1.03251427e-01 -1.04832567e-01
#  -8.78475048e-03  8.91622305e-02 -4.07985114e-02  1.24428533e-01
#   9.91876647e-02  3.89659852e-02 -4.68744710e-02  4.11489531e-02
#   1.08439669e-01 -4.61558178e-02 -1.57075286e-01 -9.74571183e-02
#   1.00514470e-02 -9.71454307e-02  1.60024539e-02  3.80917490e-02
#  -1.28361776e-01 -2.34046131e-01 -2.33048666e-02 -1.03718668e-01
#   1.61483228e-01 -5.09048216e-02  5.30933253e-02 -1.04071930e-01
#   1.10575624e-01  9.97993350e-02  2.04012871e-01 -6.29075542e-02
#  -1.26621559e-01 -1.50737375e-01  6.21911548e-02  1.07552670e-01
#  -7.60291442e-02 -2.84344889e-02 -4.81858253e-02  4.17747572e-02
#   4.44856673e-01 -7.72030428e-02 -2.91002989e-01  7.87549536e-04
#  -1.45290241e-01  2.16409937e-01 -1.58103853e-01  1.18646838e-01
#   2.03054875e-01  1.11685500e-01 -1.07858270e-01 -3.72414105e-02
#  -8.83819908e-02  1.71061203e-01 -1.65818572e-01 -1.45490631e-01
#  -2.10600957e-01  2.22077206e-01 -3.21047604e-02 -3.14507455e-01
#   6.74079433e-02  6.96743205e-02  5.51897325e-02 -2.27267839e-04
#   1.37863785e-01 -4.18681512e-03  3.08910877e-01 -8.85493122e-03
#  -2.20693536e-02 -2.16834527e-02 -7.15001896e-02  1.79472655e-01
#  -1.20040096e-01  2.32834145e-02 -6.81991875e-02  4.48548148e-04
#  -6.17838129e-02  9.80071127e-02 -6.83841994e-03 -5.60112260e-02
#   9.11352262e-02 -1.20174840e-01 -1.94817334e-01  1.10550776e-01
#  -1.97772235e-02  3.10712487e-01  2.42111483e-03 -1.21345550e-01
#   1.51888937e-01  7.01754391e-02 -5.29166497e-02 -3.71699408e-02
#  -1.59730166e-02 -2.50311524e-01  4.77008894e-02 -1.29000098e-01
#   1.03465602e-01  1.99249670e-01  1.77109510e-01  2.31374968e-02
#  -1.19591326e-01  6.77302778e-02  3.10177952e-01 -3.79673764e-02
#  -1.03312336e-01 -3.16694798e-03  2.74146274e-02 -3.77555117e-02
#   5.52709736e-02 -1.92929715e-01 -2.18416572e-01  2.75848448e-01
#   1.44172534e-01 -1.01818733e-01 -3.80262941e-01 -2.85361946e-01
#   5.59949726e-02  1.85211435e-01  2.25399211e-01  3.23985368e-02
#   1.79458976e-01  1.08983137e-01 -3.34758043e-01 -1.19075045e-01
#  -7.53490329e-02  1.20994829e-01 -5.77346571e-02 -5.54488637e-02
#  -8.56349096e-02 -4.98056598e-02 -6.16178662e-02  2.12377822e-03
#   5.16479239e-02  9.60503239e-03 -5.19912206e-02 -2.10099995e-01
#   5.91168143e-02 -2.37538934e-01  3.24480496e-02 -3.04449238e-02
#  -2.45350748e-02 -3.43563855e-02  1.71733648e-01  1.97138995e-01
#   6.64819926e-02 -1.55277133e-01 -1.19591109e-01 -2.99999386e-01
#   1.52207896e-01  7.09976107e-02 -5.74748553e-02  2.94030756e-01
#  -4.82156593e-03 -1.17134126e-02  8.07290599e-02  2.18358971e-02
#   1.35486051e-01 -1.08097501e-01 -1.38193741e-01 -3.88902985e-02
#   2.25906298e-01  2.59165347e-01  8.13257620e-02 -1.43313602e-01
#  -2.10763086e-02  8.10243562e-02  1.70620270e-02 -1.67590514e-01
#   1.02705643e-01  9.23697129e-02 -7.73800239e-02 -1.14425220e-01
#   8.76324102e-02 -9.88803245e-03  1.34790480e-01 -3.81262228e-02
#   3.37432809e-02 -6.11048751e-02  2.66780201e-02 -4.54624705e-02
#   5.07044978e-03  1.60502896e-01 -2.50469357e-01 -1.01957090e-01
#   4.00360227e-02 -2.24629324e-02  5.24361916e-02  7.14903325e-02
#  -2.38758758e-01  2.71992702e-02 -6.23874180e-02  9.04107988e-02
#  -6.73215017e-02 -5.55201853e-03 -7.23015284e-03 -8.01062509e-02
#   8.02572444e-02  1.08192094e-01  2.48175059e-02  5.83690731e-03
#  -3.54894027e-02  1.46033138e-01  1.13841020e-01  6.12493046e-02
#   5.68915755e-02 -1.28414435e-02  4.38854843e-02 -1.68926358e-01
#   1.41017839e-01  9.30660591e-03 -4.01046574e-02  8.19517374e-02
#  -1.27077386e-01 -1.60486892e-01 -3.98208834e-02 -1.75577864e-01
#   9.60098114e-03  1.60791337e-01 -1.27203301e-01  6.60730302e-02
#   8.67445543e-02 -9.90369245e-02  7.54749253e-02 -9.21997204e-02
#   3.07199592e-03 -1.03031337e-01  3.87231298e-02  4.43532839e-02
#  -1.99344441e-01 -6.58303946e-02 -9.41806938e-03 -7.91817009e-02
#   1.35948464e-01 -6.13110475e-02  7.00611994e-02  7.16529712e-02
#   6.08180948e-02 -6.92058075e-03  2.25428402e-01 -4.76021692e-02
#  -7.76370168e-02 -1.13622509e-02 -1.57526974e-02  4.66813855e-02
#  -6.86674267e-02  5.81743643e-02  8.53452981e-02  4.30763178e-02
#  -4.15640250e-02  1.69029921e-01  3.84083949e-02  5.43196127e-03
#  -1.38757512e-01  8.19350854e-02  7.58357495e-02 -9.31693763e-02
#  -1.61013007e-01  9.02223885e-02 -1.95525493e-02  1.89196184e-01
#  -8.51927400e-02  3.28256413e-02  1.14491493e-01 -9.07321870e-02
#  -1.25323040e-02 -7.72397369e-02  1.97803780e-01 -4.11500670e-02
#  -1.91880483e-02 -1.36630282e-01  6.78236112e-02 -4.53428626e-02
#   5.54920100e-02 -2.25765750e-01  1.23941198e-01  1.21874608e-01
#  -6.67658681e-03 -1.40611842e-01 -1.54609188e-01 -1.11230455e-01
#   1.10221259e-01 -2.77680028e-02 -1.42323123e-02  1.97760373e-01
#   5.23587726e-02 -3.23815495e-02 -4.66056280e-02  1.79335505e-01
#  -2.39387095e-01  2.67692596e-01  2.47276574e-01 -9.89249125e-02
#  -3.41184530e-03  2.36665141e-02 -4.48394231e-02 -6.78023919e-02
#   3.33077721e-02 -2.63787031e-01  2.73911089e-01  1.28775179e-01
#  -3.76772173e-02 -3.67473736e-02 -1.23295188e-01 -1.73586443e-01
#  -3.24648642e-03 -3.79553325e-02  1.24771625e-01  2.49196917e-01
#  -1.84917212e-01 -1.32674202e-01 -9.67079997e-02  3.51120114e-01
#  -5.95270991e-02 -3.23231786e-01 -1.62891559e-02 -8.22538361e-02
#  -1.34849980e-01  1.82131678e-02  8.66461843e-02 -2.04029232e-01
#  -3.35165501e-01  2.05922917e-01  2.98422545e-01 -4.32921723e-02
#   2.24282965e-01  8.27226322e-03  1.15375295e-01  2.14893892e-02
#   1.60686389e-01  1.05577894e-01 -3.64316434e-01  4.48790640e-02
#  -4.27316308e-01  5.12163006e-02  1.56369269e-01  1.64472744e-01
#   1.48189157e-01  1.21147335e-01 -3.51354778e-01 -1.89060420e-01
#  -4.24252957e-01 -2.19046488e-01 -2.66976923e-01 -1.74469091e-02
#  -2.57809728e-01  1.27182543e-01 -3.96192782e-02 -2.81679332e-01
#  -1.13344565e-01 -2.73508161e-01 -7.70960450e-02  4.06385288e-02
#   6.47804141e-02  8.48007575e-02  3.64559740e-02  4.84870784e-02
#  -2.03924626e-01 -1.18642509e-01 -7.08029866e-02 -1.22071922e-01
#   3.03613418e-03  9.17340070e-02 -1.14602625e-01 -4.91508916e-02
#   7.14693740e-02 -1.46279737e-01  1.40704975e-01 -1.69558778e-01
#   1.59495071e-01 -1.66186452e-01 -3.23672086e-01 -7.53047541e-02
#  -5.12898490e-02 -8.29712823e-02  1.92693353e-01 -6.86258152e-02
#  -8.46314803e-02 -1.87199250e-01  9.02117509e-03 -9.38319191e-02
#  -1.32040074e-02 -7.67778158e-02 -1.39811337e-01  2.36834124e-01
#   1.09081268e-01 -1.34421051e-01 -4.35417630e-02 -3.79225463e-01
#   8.21831636e-03 -2.18307912e-01 -9.36698020e-02  1.23993099e-01
#  -2.50892490e-02  1.15940943e-01  2.08984137e-01 -4.55418751e-02
#   1.05136298e-01  1.38792485e-01 -1.65601820e-01 -9.27175507e-02
#  -1.04319185e-01 -1.23567320e-01 -1.25473812e-01 -4.20602448e-02
#  -2.59740055e-01  2.09781304e-01 -7.46978670e-02  2.90713068e-02
#  -1.17088128e-02  1.24504596e-01  8.77928827e-03  2.95635611e-02
#  -3.15070421e-01 -6.72775060e-02 -7.40010291e-02 -1.80517808e-01
#  -1.60389483e-01 -9.37780812e-02 -1.13231778e-01 -1.50241435e-01
#   2.33626530e-01 -7.78495446e-02 -1.53733432e-01 -5.78591339e-02
#  -1.34503067e-01 -1.58522371e-02  1.83895618e-01 -1.31412089e-01
#  -6.99372441e-02 -7.70409033e-02  9.87342149e-02 -7.17884675e-02
#   1.28427178e-01  1.29653081e-01  3.16290706e-02 -1.26694320e-02
#   1.03889547e-01 -6.04331866e-02 -3.04900073e-02  1.32578462e-02
#  -4.21668887e-02 -2.68245433e-02  5.46993054e-02  1.02021180e-01
#   2.05294788e-01  3.05111054e-02  1.04540996e-01  4.17137593e-02
#   2.32100368e-01 -1.64156463e-02 -1.00877538e-01 -1.29767269e-01
#  -5.76016381e-02  4.00978513e-02  4.88009416e-02 -1.09045669e-01
#  -6.58107325e-02 -1.18168473e-01  7.07529560e-02  1.52938381e-01
#  -1.00829184e-01 -1.05559535e-01 -1.18740909e-01  2.21776649e-01
#   3.50994919e-03  1.82523489e-01 -5.40478826e-02  7.95132369e-02
#   1.00437455e-01 -5.00670783e-02  4.44371887e-02 -1.02384701e-01
#   1.50641166e-02 -1.40982747e-01  2.79425383e-01 -8.68736356e-02
#   1.31905198e-01  8.29920396e-02 -6.05105087e-02  1.68328211e-01
#  -1.34114991e-03 -3.50724161e-03 -3.93796600e-02  2.20748663e-01
#  -9.41311643e-02  2.10654996e-02  9.84150693e-02 -4.74573486e-02
#   1.70055509e-01 -2.43622974e-01 -1.63583666e-01 -5.16810194e-02
#   3.57870795e-02 -5.85866384e-02 -4.68712673e-02 -5.29511683e-02
#   1.17626809e-01  6.69455603e-02 -6.14533052e-02 -2.22821638e-01
#   8.27510729e-02 -2.26607593e-03 -1.17763087e-01  6.89050406e-02
#  -5.86223416e-02  1.78227667e-02 -1.75104976e-01 -6.76378831e-02
#  -5.63406721e-02  8.29710439e-02 -9.80779380e-02 -1.75932541e-01
#  -2.24221516e-02  1.74466163e-01 -1.10676900e-01 -4.41759117e-02
#  -4.50507216e-02  3.19034785e-01 -2.27517441e-01  1.23924399e-02
#   1.22624151e-01  1.91610783e-01  1.50721326e-01 -2.79564708e-01
#  -2.53124624e-01  2.35826299e-01 -3.59859057e-02 -1.78487003e-01
#   1.49669215e-01  3.61316167e-02  2.62102365e-01  8.74479208e-03
#   2.53152370e-01 -3.20906788e-02 -3.23903620e-01 -1.08185165e-01
#   1.57976791e-01  1.18384838e-01 -1.10663056e-01 -4.38751578e-02
#  -4.48037125e-02  1.17672212e-01 -1.28226474e-01 -1.44521790e-02
#  -3.07614189e-02 -1.86430052e-01 -1.67460348e-02 -2.28880066e-02
#  -1.43391803e-01  2.01601192e-01 -1.37288362e-01  3.22040051e-01
#  -2.36057397e-02 -2.13261336e-01  9.26746354e-02  9.41002294e-02
#  -1.13271978e-02  9.55038443e-02  1.67608652e-02 -1.08938254e-01
#  -9.13964584e-02 -1.21330313e-01  2.10581899e-01 -1.36275128e-01
#   3.59446317e-01 -1.11479901e-01  2.00085845e-02 -1.00212134e-01
#   9.16075855e-02 -5.18203415e-02  2.05196261e-01  2.25908339e-01
#   1.70116171e-01  1.82633847e-01 -8.67687017e-02 -3.36925209e-01
#  -2.18809128e-01 -2.65406817e-01  6.47135079e-02 -1.86991203e-03
#   2.53110588e-01 -6.72897473e-02 -2.31331605e-02 -3.70090678e-02
#  -2.34584525e-01  2.54277796e-01 -5.70437670e-01  7.20424801e-02
#  -1.57619286e-02  2.61405337e-04 -5.56828082e-02  6.00754097e-02
#   4.18956205e-02  1.01192676e-01 -2.33131468e-01  3.42825800e-02
#   1.27939865e-01 -1.15386128e-01  2.25536063e-01 -2.33635455e-01
#  -1.94794923e-01 -1.46611154e-01 -4.99216514e-03  6.84713339e-03
#  -1.10590234e-01 -1.07355259e-01  8.05156976e-02 -1.49472594e-01
#   4.95455228e-03 -2.91022919e-02 -3.95976678e-02 -2.00482309e-01
#  -2.17453286e-01  2.14602098e-01  5.02553396e-02 -4.24445182e-01
#   7.66568817e-03 -1.70702353e-01  6.76890612e-02  3.30272540e-02
#   7.30611458e-02 -1.65986121e-01  3.89556102e-02 -1.38552025e-01
#  -3.92456576e-02  1.67553380e-01  4.12849545e-01 -3.18441421e-01
#   7.07659870e-02  4.24143113e-02  3.93007435e-02  1.82643067e-02
#  -1.73588738e-01 -1.99393425e-02  1.13041878e-01  2.58477721e-02
#   6.60069808e-02 -8.29620212e-02 -2.20214035e-02 -7.43539408e-02
#  -1.50273770e-01 -1.70897901e-01 -1.65184453e-01 -1.93236381e-01
#  -1.11599587e-01  1.15040869e-01 -8.61993991e-04  1.94411397e-01
#  -6.72978312e-02  2.55317688e-01  5.40385060e-02 -1.12792708e-01
#   1.38341054e-01  3.20784837e-01 -1.12538233e-01 -3.67693766e-03
#   1.68674007e-01 -9.71161202e-02  2.58833319e-01  1.68617308e-01
#  -1.42015532e-01  2.98578274e-02 -3.61754969e-02  2.77966172e-01
#  -2.45317206e-01 -5.73108625e-03 -1.64870203e-01 -1.01042531e-01
#   4.03549150e-02  2.21344531e-01  7.19027072e-02  1.15230858e-01
#   1.18200257e-01 -1.39643773e-02 -3.20563912e-02  1.44348368e-01
#   1.60779268e-01 -1.02888038e-02 -4.06988375e-02 -1.99042857e-02
#  -5.37276044e-02 -7.51053244e-02 -8.93143266e-02  3.35553177e-02
#  -1.73051693e-02  3.85176688e-02  2.01324187e-03 -1.66913629e-01
#  -7.29776770e-02  1.52770415e-01 -3.96921039e-02 -1.55688494e-01
#   9.33696516e-03  8.40058625e-02  1.57822102e-01  1.22689024e-01
#  -1.04501717e-01 -3.25338240e-03 -8.97737443e-02 -5.28154336e-02
#   2.54106760e-01 -1.31237701e-01  3.97356376e-02 -2.14105193e-02
#  -1.42080158e-01  1.28025785e-01  4.01860178e-02 -2.02768743e-01
#   3.02037671e-02  2.74247825e-01 -3.46203923e-01 -3.63720283e-02
#   1.66869238e-01  1.29937261e-01 -3.50227475e-01 -8.10497627e-02
#  -4.74999994e-02  1.28145680e-01  4.02722806e-02  1.60189345e-01
#  -6.82079643e-02  6.38973415e-02  8.38129148e-02  1.07125228e-03
#   6.99190050e-03 -8.82361904e-02 -2.31487714e-02  1.42547011e-01
#   3.61115247e-01 -2.40432858e-01 -1.73079595e-01  1.97458342e-01
#  -1.14835449e-01  5.46280295e-02  1.69463307e-01  7.98422918e-02
#  -1.01458663e-02 -1.63756777e-03  2.38293502e-02 -1.38720065e-01
#  -8.80413204e-02 -2.21175253e-02  4.05960269e-02 -7.68337492e-03
#   6.25099391e-02 -2.99220607e-02 -1.09739013e-01 -1.25401750e-01
#   2.78403342e-01 -1.23551793e-01  3.96524146e-02 -2.42885008e-01
#  -1.08609810e-01 -9.95638222e-02  6.18389137e-02 -1.00720987e-01
#   2.07541719e-01  4.06853855e-02 -7.65887722e-02  8.76842737e-02
#   1.13148525e-01  2.85406451e-04  1.29826069e-01 -6.88599199e-02
#   1.11690149e-01 -6.98989034e-02 -2.43882369e-02 -6.31375164e-02
#   1.36345420e-02 -5.00085205e-02  3.07302065e-02 -4.28935997e-02
#   2.60389626e-01 -1.16711408e-01  7.66748562e-02 -1.34393305e-01]
