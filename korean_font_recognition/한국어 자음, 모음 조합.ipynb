# %%
# !pip install python-mecab-ko
# !pip install hangul-utils
from hangul_utils import join_jamos
# Out:
# ...
#      |████████████████████████████████| 296 kB 1.4 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Users/jonghyunlee/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/y1/d11dt3dd6mvd_fhmrdvqn_2w0000gn/T/pip-install-1su9pfmc/python-mecab-ko/setup.py'"'"'; __file__='"'"'/private/var/folders/y1/d11dt3dd6mvd_fhmrdvqn_2w0000gn/T/pip-install-1su9pfmc/python-mecab-ko/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/y1/d11dt3dd6mvd_fhmrdvqn_2w0000gn/T/pip-wheel-vlw9ivec
#        cwd: /private/var/folders/y1/d11dt3dd6mvd_fhmrdvqn_2w0000gn/T/pip-install-1su9pfmc/python-mecab-ko/
#   Complete output (74 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.7
# ...
